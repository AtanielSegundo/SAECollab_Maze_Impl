# %%
# !rm -r sample_data
# !git clone https://github.com/AtanielSegundo/SAECollab_Maze_Impl.git maze_impl
# !cd maze_impl && git submodule update --init --recursive
# Out:
# Cloning into 'maze_impl'...
# remote: Enumerating objects: 195, done.
# remote: Counting objects: 100% (195/195), done.
# remote: Compressing objects: 100% (135/135), done.
# remote: Total 195 (delta 106), reused 146 (delta 57), pack-reused 0 (from 0)
# Receiving objects: 100% (195/195), 115.68 KiB | 4.63 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# Submodule 'DeepLib' (https://github.com/AtanielSegundo/DeepLib) registered for path 'DeepLib'
# Submodule 'StackedCollab' (https://github.com/AtanielSegundo/stacked-nn-torch.git) registered for path 'StackedCollab'
# Submodule 'c_qlearning' (https://github.com/AtanielSegundo/c-qlearning) registered for path 'c_qlearning'
# Cloning into '/content/maze_impl/DeepLib'...
# Cloning into '/content/maze_impl/StackedCollab'...
# Cloning into '/content/maze_impl/c_qlearning'...
# Submodule path 'DeepLib': checked out '798037a60bbee9927231c356d28448ab1c7a1625'
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
FOLDER_TO_SAVE = "/content/drive/MyDrive/Otimizacao_SAE_DRL_2025/05-Mount"
# Out:
# Mounted at /content/drive

# %%
import sys
import os

sys.path.append('/content/maze_impl/')
os.chdir('/content/maze_impl') # Change current working directory to maze_impl
from ablation_experiments import *

if torch.cuda.is_available():
    print("CUDA is available! PyTorch can use the GPU.")
    print(f"Number of GPUs available: {torch.cuda.device_count()}")
    print(f"Current GPU name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available. PyTorch will use the CPU.")

experiment_1(FOLDER_TO_SAVE+"/experiment1",333,processig_mode="sequential")
# Out:
# [INFO] Starting from indices: [0, 0, 1, 2, 2, 2]
# [INFO] Completed iterations: 80/2304
# [WARNING] Cant Train Tabular Agent: [Errno 2] No such file or directory: './c_qlearning/build/agentTrain.exe'
# ...
# 📊 EXPERIMENT PROGRESS
# ...
# Progress: [█░░░░░░░░░░░░░░░░░░░░░░░░░░░░░] 3.5%
# Iteration: 81 / 2,304
#
# ⏱️  TIMING STATISTICS
#   Elapsed:        00:00:02 (2s)
#   ETA:            00:49:31 (49m 31s)
#   Avg/Iter:       1.34s
#   Speed:          0.748 iters/sec
#
# 📁 Current Path: /content/drive/MyDrive/Otimizacao_SAE_DRL_2025/05-Mount/experiment1/333/small_eg/ONE_HOT/4_H0.5O1E0.25_HReLUOIdentityEIdentity_HTOTET/DRT/M2/Hidden
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1251812124.py in <cell line: 0>()
#       6 from ablation_experiments import *
#       7
# ----> 8 experiment_1(FOLDER_TO_SAVE+"/experiment1",333,processig_mode="sequential")
#
# ...
